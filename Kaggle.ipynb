# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyani1106/kalyani/blob/kalyani/Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %% [markdown]
# Upload

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# import the Datasaet

# %%
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/competitions/data/download-all/LANL-Earthquake-Prediction

# %%
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/competitions/data/download-all/LANL-Earthquake-Prediction

# %%
# !kaggle competitions download -c LANL-Earthquake-Predictio!n
# Out:
# 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/competitions/data/download-all/LANL-Earthquake-Predictio!n

# %%
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
# 100% 2.27G/2.27G [00:30<00:00, 45.6MB/s]
# 100% 2.27G/2.27G [00:30<00:00, 80.2MB/s]

# %%
from zipfile import ZipFile
dataset='/content/LANL-Earthquake-Prediction.zip'
with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted
