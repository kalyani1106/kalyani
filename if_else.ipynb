# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyani1106/kalyani/blob/kalyani/if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **if else statements**

# %%
a=30
b=50
if(a>b):
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a=int(input("enter a num1 : "))
b=int(input("enter a num2 : "))
if(a>b):
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# enter a num1 : 5
# enter a num2 : 2
# a is greater than b

# %%
a=10
b=5
c=15
if(a>b and a>c):
  print("a is greater")
elif(b>a and b>c):
  print("b is greater")
else:
  print("c is greater")
# Out:
# c is greater
