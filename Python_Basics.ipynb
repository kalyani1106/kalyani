# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyani1106/kalyani/blob/kalyani/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
print(8+3)
# Out:
# 11

# %%
type(11)
# Out:
# int

# %%
a=10
b=5.2
c=8.99
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
a=int(input("enter fnum:"))
b=int(input("enter snum:"))
s=a+b
print(s)
# Out:
# enter fnum:4
# enter snum:2
# 6

# %%
a=5
print(float(a))
# Out:
# 5.0

# %% [markdown]
# datatypes

# %%
a=8
print(a)
type(a)
# Out:
# 8
# int

# %%
b=2.3
print(b)
type(b)
# Out:
# 2.3
# float

# %%
c=1+3j
print(3)
type(c)
# Out:
# 3
# complex

# %%
a=True
print(a)
type(a)
# Out:
# True
# bool

# %%
a=7<3
type(a)
# Out:
# bool

# %%
print("Hello "*5)
# Out:
# Hello Hello Hello Hello Hello

# %%
str="kalyani"
print(str[0:8])
print(str[0:8:2])
# Out:
# kalyani
# klai

# %%
a="kalyani"
b="vamsi"
print(a+b)
# Out:
# kalyanivamsi
